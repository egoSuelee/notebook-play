# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd

print(pd.__version__)

names = ['bob', 'jack', 'tom', 'rose', 'mary']
births = ['1992-01-11', '1995-01-08', '1992-11-11', '1992-10-22', '1992-08-21']

people = list(zip(names, birth))
print(people)
# Out:
# 0.20.3
# [('bob', '1992-01-11'), ('jack', '1995-01-08'), ('tom', '1992-11-11'), ('rose', '1992-10-22'), ('mary', '1992-08-21')]

# %%
df = pd.DataFrame(data = people, columns = ['Names', 'Births'])
df
# Out:
#   Names      Births
# 0   bob  1992-01-11
# 1  jack  1995-01-08
# 2   tom  1992-11-11
# 3  rose  1992-10-22
# 4  mary  1992-08-21

# %%
df.to_csv('births1880.csv', index = False, header = False)

# %%
file_path =r'/Users/xwy_brh/Downloads/AI/notebook-play/births1880.csv'
rf = pd.read_csv(file_path, header = None, names = ["Names", "Births"])
rf
# Out:
#   Names      Births
# 0   bob  1992-01-11
# 1  jack  1995-01-08
# 2   tom  1992-11-11
# 3  rose  1992-10-22
# 4  mary  1992-08-21

# %%
import os
os.remove(file_path)

# %%
stock_file_path = r'/Users/xwy_brh/Downloads/AI/dataSets/stock_train_data_20170901.csv'
sf = pd.read_csv(stock_file_path, nrows=300)
sf
# Out:
#       id  feature0  feature1  feature2  feature3  feature4  feature5  \
# 0      0 -1.173882  1.538027  1.275714 -0.013584 -2.546444  1.087728
# 1      1 -1.178808  1.397968  0.901504  1.469173 -2.179160  0.410564
# 2      2 -1.114238  1.026806 -1.393255  1.175937 -0.868198  0.660903
# 3      3 -0.664808  1.108403 -0.894371  0.883911 -0.592890  0.235681
# 4      4 -0.392408  1.389080  0.040249  4.006332 -1.629613  0.553216
# 5      5 -0.400484 -0.587553  1.404753 -0.355609 -0.824592  1.088633
# 6      6 -1.260995 -1.297146 -1.397739  0.237993 -1.535000  0.964815
# 7      7 -0.655226  0.719243 -0.448219  2.592721 -1.968366  1.092013
# 8      8  0.340032  0.303219  0.440998  1.144836  0.103850 -1.117281
# 9      9 -0.170870 -0.992091  1.501305  1.037615 -0.366572 -1.154542
# 10    10 -0.497007  1.336646 -0.964323  4.337978 -0.702962  0.263371
# 11    11 -0.753392 -0.947149 -0.208691  0.967405 -1.669028  1.014876
# 12    12  0.542437  0.991069 -0.979245 -0.728891  0.206301 -1.090838
# ...

# %% [markdown]
# ## [10 Minutes to pandas](http://pandas.pydata.org/pandas-docs/stable/10min.html#min)

# %%
import numpy as np
import pandas as pd
import matplotlib.pylot as plt

# %% [markdown]
# ### 在pandas库中, 主要使用了两个数据类型结构
# 1. <em>Series</em>
#     <br>
#     ps.[参考链接](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.html#pandas.Series)
# ```
#     class pandas.Series(data=None, index=None, dtype=None, name=None, copy=False, fastpath=False)[source]
# ```
# 2. DataFrame
#     有点像数据库的结构

# %%
s = pd.Series([1, 3, 5, np.nan, 43, 9.8])
s
# Out:
# 0     1.0
# 1     3.0
# 2     5.0
# 3     NaN
# 4    43.0
# 5     9.8
# dtype: float64

# %%
dates = pd.date_range('20170920', periods = 6)
dates
# Out:
# DatetimeIndex(['2017-09-20', '2017-09-21', '2017-09-22', '2017-09-23',
#                '2017-09-24', '2017-09-25'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.rand(6, 5), index = dates, columns = list('ABCDE'))
df
# Out:
#                    A         B         C         D         E
# 2017-09-20  0.761733  0.120397  0.521084  0.850656  0.977919
# 2017-09-21  0.873333  0.112119  0.506629  0.629526  0.218005
# 2017-09-22  0.233203  0.140803  0.200781  0.913022  0.382804
# 2017-09-23  0.796658  0.088113  0.482258  0.835864  0.981236
# 2017-09-24  0.333129  0.479810  0.179533  0.414468  0.679449
# 2017-09-25  0.736676  0.471260  0.109521  0.320464  0.065104

# %%
df2 = pd.DataFrame({ 'A':1.,
    'B': pd.Timestamp('20170920'),
    'C': pd.Series(1, index = list(range(4)), dtype='float32'),
    'D': np.array([3] * 4, dt